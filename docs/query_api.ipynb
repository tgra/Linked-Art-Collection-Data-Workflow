# %% [markdown]
# # How to query PIA JSON API with query_api.py
#
# ## Introduction
#
# The query_api.py file queries the PIA JSON API and writes the JSON files returned to a local directory, ready for transformation to Linked Art JSON-LD.
#
# A .yaml file is used for script variables. The filepath for the .yaml file is specified as a script argument --config
#
# ## Example settings.yaml  file
#
# A settings.yaml file is specified in the script argument --config.
#
# An example config file can be viewed at [example settings.yaml](/digitalobject/settings.yaml)
#
# Example content:
#
# ```yaml
# - - - # settings for digital object
# - settings:
#   default_lang        : en
#   base_url            : https://linkedart.participatory-archives.ch/
#   pia_api_uri         : https://data.participatory-archives.ch/api/v1/images
#   pia_api_include     : include=collections,date,place
#   page_size           : 500
#   directory           : digitalobject/
#   a_collection        : data/a_collection
#   b_mapped            : data/b_mapped
#   c_linked_art        : data/c_linked_art
#   template            : template.jsonnet
# ...
# ```
#
# The query URL for the PIA API query is contstructed using 'pia_api_url' and 'pia_api_include' in the settings.yaml file
#
# JSON files are written to a local directory, with the filepath constructed using the 'directory', 'a_collection' and 'page_size' variables in the setting.yaml file.
#
#
# ## Files
# - query_api.py - main script
# - settings.py - use function 'query_api()' to check that the correct script arguments have been provided
#
#
# ## Help
# The following will provide information about arguments to use with the script.
# ```
# python3 query_api.py -h
# ```
#
# ## Example command
#
# ```python
# query_api.py  --config <config-file>
# ```
# e.g.
# ```python
# python3 query_api.py --config ./digitalobject/settings.yaml
# ```
#
# ## Load Python packages

# %%
import json
import requests
import sys
import traceback
import yaml
from yaml.loader import SafeLoader

# %% [markdown]
# ## Read in config file
#
# Usually command line argument `--config` but added as var `config_file` here

# %%
# commented out as not using command line argument for config file
# settings.py in local dir
#import settings

config_file = "../digitalobject/settings.yaml"

with open(config_file) as f:
    data = (yaml.load(f, Loader=SafeLoader))
    
    config = data[1]

config
# Out:
# {'settings': None,
#  'default_lang': 'en',
#  'base_url': 'https://linkedart.participatory-archives.ch/',
#  'pia_api_uri': 'https://data.participatory-archives.ch/api/v1/images',
#  'pia_api_include': 'include=collections,date,place',
#  'page_size': 500,
#  'directory': 'digitalobject/',
#  'a_collection': 'data/a_collection',
#  'b_mapped': 'data/b_mapped',
#  'c_linked_art': 'data/c_linked_art',
#  'template': 'template.jsonnet'}

# %% [markdown]
# ## Option to modify the config settings
# If you'd like to try different settings, update the config dictionary in the next code cell e.g. config["directory"] = "../digitalobject/"

# %%
config["directory"] = "../digitalobject/" # directory to save files to

config["page_size"] = 200 # number of records to return with each API query

config["pia_api_uri"] = 'https://data.participatory-archives.ch/api/v1/images' # PIA API to query

config["pia_api_include"] = 'include=collections,date,place' # additional data to include for each record returned with API call

# %% [markdown]
# ## Construct API Query URL
# get config variables, ready to construct API query URL

# %%
# dir to store collection data files
a_collection = config["directory"] + config["a_collection"]

# number of records to return per page
page_size = config["page_size"]

# default total number of pages to return - actual number will be determined by call to API
total_pages = 1


# URI for PIA API
api_uri = config["pia_api_uri"]
api_include = ""
if config["pia_api_include"] != None:
    api_include = config["pia_api_include"]

# %% [markdown]
# ## Query API to get total pages in resultset
#
# initial query of API to get total number of pages, to iterate through in next step

# %%
# get total number of pages
query_total_pages = api_uri + "?page[number]=1&page[size]=" + str(page_size)
response = requests.get(query_total_pages)
result = response.json()

# get total pages from api call
total_pages = result["meta"]["page"]["lastPage"]


# construct query to return data
query = api_uri + "?" + api_include + "&page[size]=" + str(page_size)

print("total pages: " + str(total_pages))
# Out:
# total pages: 300

# %% [markdown]
# ## Query API and write files to local directory

# %%
# QUERY API

print("saving files to: " + a_collection)

# iterate through paged records
for page in range(1, total_pages + 1):
    # add page number to query
    query1 = query + "&page[number]=" + str(page)
    print('\n' + query1, end='', flush=True)
    # use try statement to pick up errors
    try:
        # query api
        response = requests.get(query1)
        json_data = response.json()

        # write file to collection data dir
        text_file = open(a_collection + "/" + str(page) + ".json", "wt")
        n = text_file.write(json.dumps(json_data, indent=2))
        text_file.close()

    except Exception as e:
        traceback.print_exc()
        sys.exit(1)

print("script completed")
# Out:
# saving files to: ../digitalobject/data/a_collection
#
# 1.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=1
# 2.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=2
# 3.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=3
# 4.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=4
# 5.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=5
# 6.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=6
# 7.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=7
# 8.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=8
# 9.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=9
# 10.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=10
# 11.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=11
# 12.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=12
# 13.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=13
# 14.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=14
# 15.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=15
# 16.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=16
# 17.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=17
# 18.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=18
# 19.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=19
# 20.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=20
# 21.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=21
# 22.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=22
# 23.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=23
# 24.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=24
# 25.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=25
# 26.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=26
# 27.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=27
# 28.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=28
# 29.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=29
# 30.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=30
# 31.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=31
# 32.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=32
# 33.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=33
# 34.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=34
# 35.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=35
# 36.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=36
# 37.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=37
# 38.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=38
# 39.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=39
# 40.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=40
# 41.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=41
# 42.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=42
# 43.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=43
# 44.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=44
# 45.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=45
# 46.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=46
# 47.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=47
# 48.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=48
# 49.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=49
# 50.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=50
# 51.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=51
# 52.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=52
# 53.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=53
# 54.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=54
# 55.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=55
# 56.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=56
# 57.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=57
# 58.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=58
# 59.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=59
# 60.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=60
# 61.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=61
# 62.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=62
# 63.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=63
# 64.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=64
# 65.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=65
# 66.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=66
# 67.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=67
# 68.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=68
# 69.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=69
# 70.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=70
# 71.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=71
# 72.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=72
# 73.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=73
# 74.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=74
# 75.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=75
# 76.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=76
# 77.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=77
# 78.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=78
# 79.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=79
# 80.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=80
# 81.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=81
# 82.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=82
# 83.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=83
# 84.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=84
# 85.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=85
# 86.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=86
# 87.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=87
# 88.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=88
# 89.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=89
# 90.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=90
# 91.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=91
# 92.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=92
# 93.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=93
# 94.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=94
# 95.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=95
# 96.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=96
# 97.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=97
# 98.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=98
# 99.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=99
# 100.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=100
# 101.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=101
# 102.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=102
# 103.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=103
# 104.
# https://data.participatory-archives.ch/api/v1/images?include=collections,date,place&page[size]=200&page[number]=104
# Traceback (most recent call last):
#   File "<ipython-input-10-70cb9eb4af64>", line 15, in <module>
#     json_data = response.json()
#   File "/opt/anaconda3/lib/python3.8/site-packages/requests/models.py", line 910, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.8/json/__init__.py", line 357, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.8/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.8/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# 2022-09-08 12:22:29,174 [42080] ERROR    root:152: [JupyterRequire] Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "<ipython-input-10-70cb9eb4af64>", line 15, in <module>
#     json_data = response.json()
#   File "/opt/anaconda3/lib/python3.8/site-packages/requests/models.py", line 910, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.8/json/__init__.py", line 357, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.8/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.8/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-70cb9eb4af64>", line 24, in <module>
#     sys.exit(1)
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/anaconda3/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-10-70cb9eb4af64> in <module>
#      14         response = requests.get(query1)
# ---> 15         json_data = response.json()
#      16
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#
# /opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#
# /opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-10-70cb9eb4af64> in <module>
#      23         traceback.print_exc()
# ---> 24         sys.exit(1)
#      25
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2055                     stb = ['An exception has occurred, use %tb to see '
#    2056                            'the full traceback.\n']
# -> 2057                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2058                                                                      value))
#    2059                 else:
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     627             chained_exceptions_tb_offset = 0
#     628             out_list = (
# --> 629                 self.structured_traceback(
#     630                     etype, evalue, (etb, chained_exc_ids),
#     631                     chained_exceptions_tb_offset, context)
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
