# %% [markdown]
# # How to map collection data to intermediate JSON format with map_data.py
#
# ## Introduction
#
# The `map_data.py` file maps collection data in JSON format, retrieved from the PIA JSON API, to an intermediate JSON format.
#
#
# A .yaml file is used for script variables. The filepath for the .yaml file is specified as a script argument --config
#
# ## Example settings.yaml  file
#
# A settings.yaml file is specified in the script argument --config.
#
# An example config file can be viewed at [example settings.yaml](/digitalobject/settings.yaml)
#
# Example content:
#
# ```yaml
# - - - # settings for digital object
# - settings:
#   default_lang        : en
#   base_url            : https://data.participatory-archives.ch/
#   pia_api_uri         : https://json.participatory-archives.ch/api/v1/images
#   pia_api_include     : include=collections,date,place
#   page_size           : 500
#   directory           : digitalobject/
#   a_collection        : data/a_collection
#   b_mapped            : data/b_mapped
#   c_linked_art        : data/c_linked_art
#   template            : template.jsonnet
# ...
# ```
#
#
# ## Files
# - map_data.py - main script
# - map_data_func.py
# - template.jsonnet - JSON template for intermediate JSON file to be populated with collection data
# - settings.py - use function 'query_api()' to check that the correct script arguments have been provided
# - digitalobject/data/a_collection/*.json - collection data files from PIA JSON API
# - digitalobject/data/b_mapped/*.json - output JSON files
#
# ## Help
# The following will provide information about arguments to use with the script.
# ```
# python3 map_data.py -h
# ```
#
# ## Example command
#
# ```python
# map_data.py --objtype <objecttype> --config <config-file> --template <jsonnet-template-filepath>
# ```
# e.g.
# ```python
# python3 map_data.py --objtype set --config set/settings.yaml --template set/template.jsonnet
#
# ```
#
# `--objtype` is one of:
# - `humanmadeobject`
# - `digitalobject`
# - `set`

# %% [markdown]
# ## Import Python libraries and local functions
#
# Imports Python libraries and locally-defined functions in map_data_func.py

# %%
import json
import os
from os import walk
from pathlib import Path
import yaml
from yaml.loader import SafeLoader


# %pip install jsonnet
# mapping functions in local dir
import map_data_func
# Out:
# Requirement already satisfied: jsonnet in /opt/anaconda3/lib/python3.8/site-packages (0.18.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Get settings
# - Commented out use of settings.py
# - Using inline variables instead

# %%
# settings.py in local dir
# commented out for jupyter notebook
#import settings
#[objtype, config_file, template] = settings.map_data()

objtype = 'digitalobject'
config_file = 'digitalobject/settings.yaml'
template = 'digitalobject/template.jsonnet'

# %% [markdown]
# ## Read settings in configuration file

# %%
# ===============================================
# READ IN CONFIG

with open(config_file) as f:
    data = yaml.load(f, Loader=SafeLoader)
    config = data[1]

    
print(config_file)

directory = config["directory"]
a_collection = directory + config["a_collection"] # dir to store collection data files
b_mapped = directory + config["b_mapped"] # dir to store mapped data
template = Path(template).read_text() # jsonnet template for intermediate JSON data file
# Out:
# digitalobject/settings.yaml

# %%
## ===============================================

# ITERATE OVER FILES IN COLLECTION DATA DIR

files = []
for (dirpath, dirnames, filenames) in walk(a_collection):
    files.extend(filenames)
    break
files.sort()

for file in files:
    filename = os.path.basename(file)
    print("Processing file: " + filename)  
    # open file 
    with open(a_collection + '/' + file) as json_file:
        filename = os.path.basename(file)
        # load data into python dict
        data = json.load(json_file)
            
        # create lists for additional image, date and place data identified in record
        
        mapped_data = None

        # iterate over included data and append  date, collection and place data to lists
        if "included" in data:
            include_data = []
            data_dates  = []
            data_places = []
            data_collections = []

            for record in data["included"]:
                if record["type"] == "dates":
                    data_dates.append(record)
                elif record["type"] == "places":
                    data_places.append(record) 
                elif record["type"] == "collections":
                    data_collections.append(record)            
            include_data = [data_dates,data_places,data_collections]

        # map data for digital object and humanmadeobject
        if objtype in ["humanmadeobject","digitalobject"]:
            data_images = []
            for record in data["data"]:
                if record["type"] == "images":
                    if objtype == "digitalobject" and record["attributes"]["base_path"] == "SGV_10":
                        data_images.append(record)
                    elif objtype == "humanmadeobject" and record["attributes"]["base_path"] == "SGV_12":
                        data_images.append(record)
            for record in data_images:
                json_data = map_data_func.images(record,template, include_data)
                
                map_data_func.save_file(json_data,b_mapped, record["id"])
        
        # map collection data
        if objtype == 'set':
            for record in data["data"]:
                if record["type"] == "collections":
                    json_data = map_data_func.set(record,template)
                    map_data_func.save_file(json_data, b_mapped, record["id"])
# Out:
# Processing file: 1.json
#
#  saving mapped collection data file: digitalobject/data/b_mapped/1.json
#  saving mapped collection data file: digitalobject/data/b_mapped/2.json
#  saving mapped collection data file: digitalobject/data/b_mapped/3.json
#  saving mapped collection data file: digitalobject/data/b_mapped/4.json
#  saving mapped collection data file: digitalobject/data/b_mapped/5.json
#  saving mapped collection data file: digitalobject/data/b_mapped/6.json
#  saving mapped collection data file: digitalobject/data/b_mapped/7.json
#  saving mapped collection data file: digitalobject/data/b_mapped/8.json
#  saving mapped collection data file: digitalobject/data/b_mapped/9.json
#  saving mapped collection data file: digitalobject/data/b_mapped/10.json
#  saving mapped collection data file: digitalobject/data/b_mapped/11.json
#  saving mapped collection data file: digitalobject/data/b_mapped/12.json
#  saving mapped collection data file: digitalobject/data/b_mapped/13.json
#  saving mapped collection data file: digitalobject/data/b_mapped/14.json
#  saving mapped collection data file: digitalobject/data/b_mapped/15.json
#  saving mapped collection data file: digitalobject/data/b_mapped/16.json
#  saving mapped collection data file: digitalobject/data/b_mapped/17.json
#  saving mapped collection data file: digitalobject/data/b_mapped/18.json
#  saving mapped collection data file: digitalobject/data/b_mapped/19.json
#  saving mapped collection data file: digitalobject/data/b_mapped/20.json
#  saving mapped collection data file: digitalobject/data/b_mapped/21.json
#  saving mapped collection data file: digitalobject/data/b_mapped/22.json
#  saving mapped collection data file: digitalobject/data/b_mapped/23.json
#  saving mapped collection data file: digitalobject/data/b_mapped/24.json
#  saving mapped collection data file: digitalobject/data/b_mapped/25.json
#  saving mapped collection data file: digitalobject/data/b_mapped/26.json
#  saving mapped collection data file: digitalobject/data/b_mapped/27.json
#  saving mapped collection data file: digitalobject/data/b_mapped/28.json
#  saving mapped collection data file: digitalobject/data/b_mapped/29.json
#  saving mapped collection data file: digitalobject/data/b_mapped/30.json
#  saving mapped collection data file: digitalobject/data/b_mapped/31.json
#  saving mapped collection data file: digitalobject/data/b_mapped/32.json
#  saving mapped collection data file: digitalobject/data/b_mapped/33.json
#  saving mapped collection data file: digitalobject/data/b_mapped/34.json
#  saving mapped collection data file: digitalobject/data/b_mapped/35.json
#  saving mapped collection data file: digitalobject/data/b_mapped/36.json
#  saving mapped collection data file: digitalobject/data/b_mapped/37.json
#  saving mapped collection data file: digitalobject/data/b_mapped/38.json
#  saving mapped collection data file: digitalobject/data/b_mapped/39.json
#  saving mapped collection data file: digitalobject/data/b_mapped/40.json
#  saving mapped collection data file: digitalobject/data/b_mapped/41.json
#  saving mapped collection data file: digitalobject/data/b_mapped/42.json
#  saving mapped collection data file: digitalobject/data/b_mapped/43.json
#  saving mapped collection data file: digitalobject/data/b_mapped/44.json
#  saving mapped collection data file: digitalobject/data/b_mapped/45.json
#  saving mapped collection data file: digitalobject/data/b_mapped/46.json
#  saving mapped collection data file: digitalobject/data/b_mapped/47.json
#  saving mapped collection data file: digitalobject/data/b_mapped/48.json
#  saving mapped collection data file: digitalobject/data/b_mapped/49.json
#  saving mapped collection data file: digitalobject/data/b_mapped/50.json
#  saving mapped collection data file: digitalobject/data/b_mapped/51.json
#  saving mapped collection data file: digitalobject/data/b_mapped/52.json
#  saving mapped collection data file: digitalobject/data/b_mapped/53.json
#  saving mapped collection data file: digitalobject/data/b_mapped/54.json
#  saving mapped collection data file: digitalobject/data/b_mapped/55.json
#  saving mapped collection data file: digitalobject/data/b_mapped/56.json
#  saving mapped collection data file: digitalobject/data/b_mapped/57.json
#  saving mapped collection data file: digitalobject/data/b_mapped/58.json
#  saving mapped collection data file: digitalobject/data/b_mapped/59.json
#  saving mapped collection data file: digitalobject/data/b_mapped/60.json
#  saving mapped collection data file: digitalobject/data/b_mapped/61.json
#  saving mapped collection data file: digitalobject/data/b_mapped/62.json
#  saving mapped collection data file: digitalobject/data/b_mapped/63.json
#  saving mapped collection data file: digitalobject/data/b_mapped/64.json
#  saving mapped collection data file: digitalobject/data/b_mapped/65.json
#  saving mapped collection data file: digitalobject/data/b_mapped/66.json
#  saving mapped collection data file: digitalobject/data/b_mapped/67.json
#  saving mapped collection data file: digitalobject/data/b_mapped/68.json
#  saving mapped collection data file: digitalobject/data/b_mapped/69.json
#  saving mapped collection data file: digitalobject/data/b_mapped/70.json
#  saving mapped collection data file: digitalobject/data/b_mapped/71.json
#  saving mapped collection data file: digitalobject/data/b_mapped/72.json
#  saving mapped collection data file: digitalobject/data/b_mapped/73.json
#  saving mapped collection data file: digitalobject/data/b_mapped/74.json
#  saving mapped collection data file: digitalobject/data/b_mapped/75.json
#  saving mapped collection data file: digitalobject/data/b_mapped/76.json
#  saving mapped collection data file: digitalobject/data/b_mapped/77.json
#  saving mapped collection data file: digitalobject/data/b_mapped/78.json
#  saving mapped collection data file: digitalobject/data/b_mapped/79.json
#  saving mapped collection data file: digitalobject/data/b_mapped/80.json
#  saving mapped collection data file: digitalobject/data/b_mapped/81.json
#  saving mapped collection data file: digitalobject/data/b_mapped/82.json
#  saving mapped collection data file: digitalobject/data/b_mapped/83.json
#  saving mapped collection data file: digitalobject/data/b_mapped/84.json
#  saving mapped collection data file: digitalobject/data/b_mapped/85.json
#  saving mapped collection data file: digitalobject/data/b_mapped/86.json
#  saving mapped collection data file: digitalobject/data/b_mapped/87.json
#  saving mapped collection data file: digitalobject/data/b_mapped/88.json
#  saving mapped collection data file: digitalobject/data/b_mapped/89.json
#  saving mapped collection data file: digitalobject/data/b_mapped/90.json
#  saving mapped collection data file: digitalobject/data/b_mapped/91.json
#  saving mapped collection data file: digitalobject/data/b_mapped/92.json
#  saving mapped collection data file: digitalobject/data/b_mapped/93.json
#  saving mapped collection data file: digitalobject/data/b_mapped/94.json
#  saving mapped collection data file: digitalobject/data/b_mapped/95.json
#  saving mapped collection data file: digitalobject/data/b_mapped/96.json
#  saving mapped collection data file: digitalobject/data/b_mapped/97.json
#  saving mapped collection data file: digitalobject/data/b_mapped/98.json
#  saving mapped collection data file: digitalobject/data/b_mapped/99.json
#  saving mapped collection data file: digitalobject/data/b_mapped/100.json
#  saving mapped collection data file: digitalobject/data/b_mapped/101.json
#  saving mapped collection data file: digitalobject/data/b_mapped/102.json
#  saving mapped collection data file: digitalobject/data/b_mapped/103.json
#  saving mapped collection data file: digitalobject/data/b_mapped/104.json
#  saving mapped collection data file: digitalobject/data/b_mapped/105.json
#  saving mapped collection data file: digitalobject/data/b_mapped/106.json
#  saving mapped collection data file: digitalobject/data/b_mapped/107.json
#  saving mapped collection data file: digitalobject/data/b_mapped/108.json
#  saving mapped collection data file: digitalobject/data/b_mapped/109.json
#  saving mapped collection data file: digitalobject/data/b_mapped/110.json
#  saving mapped collection data file: digitalobject/data/b_mapped/111.json
#  saving mapped collection data file: digitalobject/data/b_mapped/112.json
#  saving mapped collection data file: digitalobject/data/b_mapped/113.json
#  saving mapped collection data file: digitalobject/data/b_mapped/114.json
#  saving mapped collection data file: digitalobject/data/b_mapped/115.json
#  saving mapped collection data file: digitalobject/data/b_mapped/116.json
#  saving mapped collection data file: digitalobject/data/b_mapped/117.json
#  saving mapped collection data file: digitalobject/data/b_mapped/118.json
#  saving mapped collection data file: digitalobject/data/b_mapped/119.json
#  saving mapped collection data file: digitalobject/data/b_mapped/120.json
#  saving mapped collection data file: digitalobject/data/b_mapped/121.json
#  saving mapped collection data file: digitalobject/data/b_mapped/122.json
#  saving mapped collection data file: digitalobject/data/b_mapped/123.json
#  saving mapped collection data file: digitalobject/data/b_mapped/124.json
#  saving mapped collection data file: digitalobject/data/b_mapped/125.json
#  saving mapped collection data file: digitalobject/data/b_mapped/126.json
#  saving mapped collection data file: digitalobject/data/b_mapped/127.json
#  saving mapped collection data file: digitalobject/data/b_mapped/128.json
#  saving mapped collection data file: digitalobject/data/b_mapped/129.json
#  saving mapped collection data file: digitalobject/data/b_mapped/130.json
#  saving mapped collection data file: digitalobject/data/b_mapped/131.json
#  saving mapped collection data file: digitalobject/data/b_mapped/132.json
#  saving mapped collection data file: digitalobject/data/b_mapped/133.json
#  saving mapped collection data file: digitalobject/data/b_mapped/134.json
#  saving mapped collection data file: digitalobject/data/b_mapped/135.json
#  saving mapped collection data file: digitalobject/data/b_mapped/136.json
#  saving mapped collection data file: digitalobject/data/b_mapped/137.json
#  saving mapped collection data file: digitalobject/data/b_mapped/138.json
#  saving mapped collection data file: digitalobject/data/b_mapped/139.json
#  saving mapped collection data file: digitalobject/data/b_mapped/140.json
#  saving mapped collection data file: digitalobject/data/b_mapped/141.json
#  saving mapped collection data file: digitalobject/data/b_mapped/142.json
#  saving mapped collection data file: digitalobject/data/b_mapped/143.json
#  saving mapped collection data file: digitalobject/data/b_mapped/144.json
#  saving mapped collection data file: digitalobject/data/b_mapped/145.json
#  saving mapped collection data file: digitalobject/data/b_mapped/146.json
#  saving mapped collection data file: digitalobject/data/b_mapped/147.json
#  saving mapped collection data file: digitalobject/data/b_mapped/148.json
#  saving mapped collection data file: digitalobject/data/b_mapped/149.json
#  saving mapped collection data file: digitalobject/data/b_mapped/150.json
#  saving mapped collection data file: digitalobject/data/b_mapped/151.json
#  saving mapped collection data file: digitalobject/data/b_mapped/152.json
#  saving mapped collection data file: digitalobject/data/b_mapped/153.json
#  saving mapped collection data file: digitalobject/data/b_mapped/154.json
#  saving mapped collection data file: digitalobject/data/b_mapped/155.json
#  saving mapped collection data file: digitalobject/data/b_mapped/156.json
#  saving mapped collection data file: digitalobject/data/b_mapped/157.json
#  saving mapped collection data file: digitalobject/data/b_mapped/158.json
#  saving mapped collection data file: digitalobject/data/b_mapped/159.json
#  saving mapped collection data file: digitalobject/data/b_mapped/160.json
#  saving mapped collection data file: digitalobject/data/b_mapped/161.json
#  saving mapped collection data file: digitalobject/data/b_mapped/162.json
#  saving mapped collection data file: digitalobject/data/b_mapped/163.json
#  saving mapped collection data file: digitalobject/data/b_mapped/164.json
#  saving mapped collection data file: digitalobject/data/b_mapped/165.json
#  saving mapped collection data file: digitalobject/data/b_mapped/166.json
#  saving mapped collection data file: digitalobject/data/b_mapped/167.json
#  saving mapped collection data file: digitalobject/data/b_mapped/168.json
#  saving mapped collection data file: digitalobject/data/b_mapped/169.json
#  saving mapped collection data file: digitalobject/data/b_mapped/170.json
#  saving mapped collection data file: digitalobject/data/b_mapped/171.json
#  saving mapped collection data file: digitalobject/data/b_mapped/172.json
#  saving mapped collection data file: digitalobject/data/b_mapped/173.json
#  saving mapped collection data file: digitalobject/data/b_mapped/174.json
#  saving mapped collection data file: digitalobject/data/b_mapped/175.json
#  saving mapped collection data file: digitalobject/data/b_mapped/176.json
#  saving mapped collection data file: digitalobject/data/b_mapped/177.json
#  saving mapped collection data file: digitalobject/data/b_mapped/178.json
#  saving mapped collection data file: digitalobject/data/b_mapped/179.json
#  saving mapped collection data file: digitalobject/data/b_mapped/180.json
#  saving mapped collection data file: digitalobject/data/b_mapped/181.json
#  saving mapped collection data file: digitalobject/data/b_mapped/182.json
#  saving mapped collection data file: digitalobject/data/b_mapped/183.json
#  saving mapped collection data file: digitalobject/data/b_mapped/184.json
#  saving mapped collection data file: digitalobject/data/b_mapped/185.json
#  saving mapped collection data file: digitalobject/data/b_mapped/186.json
#  saving mapped collection data file: digitalobject/data/b_mapped/187.json
#  saving mapped collection data file: digitalobject/data/b_mapped/188.json
#  saving mapped collection data file: digitalobject/data/b_mapped/189.json
#  saving mapped collection data file: digitalobject/data/b_mapped/190.json
#  saving mapped collection data file: digitalobject/data/b_mapped/191.json
#  saving mapped collection data file: digitalobject/data/b_mapped/192.json
#  saving mapped collection data file: digitalobject/data/b_mapped/193.json
#  saving mapped collection data file: digitalobject/data/b_mapped/194.json
#  saving mapped collection data file: digitalobject/data/b_mapped/195.json
#  saving mapped collection data file: digitalobject/data/b_mapped/196.json
#  saving mapped collection data file: digitalobject/data/b_mapped/197.json
#  saving mapped collection data file: digitalobject/data/b_mapped/198.json
#  saving mapped collection data file: digitalobject/data/b_mapped/199.json
#  saving mapped collection data file: digitalobject/data/b_mapped/200.json
#  saving mapped collection data file: digitalobject/data/b_mapped/201.json
#  saving mapped collection data file: digitalobject/data/b_mapped/202.json
#  saving mapped collection data file: digitalobject/data/b_mapped/203.json
#  saving mapped collection data file: digitalobject/data/b_mapped/204.json
#  saving mapped collection data file: digitalobject/data/b_mapped/205.json
#  saving mapped collection data file: digitalobject/data/b_mapped/206.json
#  saving mapped collection data file: digitalobject/data/b_mapped/207.json
#  saving mapped collection data file: digitalobject/data/b_mapped/208.json
#  saving mapped collection data file: digitalobject/data/b_mapped/209.json
#  saving mapped collection data file: digitalobject/data/b_mapped/210.json
#  saving mapped collection data file: digitalobject/data/b_mapped/211.json
#  saving mapped collection data file: digitalobject/data/b_mapped/212.json
#  saving mapped collection data file: digitalobject/data/b_mapped/213.json
#  saving mapped collection data file: digitalobject/data/b_mapped/214.json
#  saving mapped collection data file: digitalobject/data/b_mapped/215.json
#  saving mapped collection data file: digitalobject/data/b_mapped/216.json
#  saving mapped collection data file: digitalobject/data/b_mapped/217.json
#  saving mapped collection data file: digitalobject/data/b_mapped/218.json
#  saving mapped collection data file: digitalobject/data/b_mapped/219.json
#  saving mapped collection data file: digitalobject/data/b_mapped/220.json
#  saving mapped collection data file: digitalobject/data/b_mapped/221.json
#  saving mapped collection data file: digitalobject/data/b_mapped/222.json
#  saving mapped collection data file: digitalobject/data/b_mapped/223.json
#  saving mapped collection data file: digitalobject/data/b_mapped/224.json
#  saving mapped collection data file: digitalobject/data/b_mapped/225.json
#  saving mapped collection data file: digitalobject/data/b_mapped/226.json
#  saving mapped collection data file: digitalobject/data/b_mapped/227.json
#  saving mapped collection data file: digitalobject/data/b_mapped/228.json
#  saving mapped collection data file: digitalobject/data/b_mapped/229.json
#  saving mapped collection data file: digitalobject/data/b_mapped/230.json
#  saving mapped collection data file: digitalobject/data/b_mapped/231.json
#  saving mapped collection data file: digitalobject/data/b_mapped/232.json
#  saving mapped collection data file: digitalobject/data/b_mapped/233.json
#  saving mapped collection data file: digitalobject/data/b_mapped/234.json
#  saving mapped collection data file: digitalobject/data/b_mapped/235.json
#  saving mapped collection data file: digitalobject/data/b_mapped/236.json
#  saving mapped collection data file: digitalobject/data/b_mapped/237.json
#  saving mapped collection data file: digitalobject/data/b_mapped/238.json
#  saving mapped collection data file: digitalobject/data/b_mapped/239.json
#  saving mapped collection data file: digitalobject/data/b_mapped/240.json
#  saving mapped collection data file: digitalobject/data/b_mapped/241.json
#  saving mapped collection data file: digitalobject/data/b_mapped/242.json
#  saving mapped collection data file: digitalobject/data/b_mapped/243.json
#  saving mapped collection data file: digitalobject/data/b_mapped/244.json
#  saving mapped collection data file: digitalobject/data/b_mapped/245.json
#  saving mapped collection data file: digitalobject/data/b_mapped/246.json
#  saving mapped collection data file: digitalobject/data/b_mapped/247.json
#  saving mapped collection data file: digitalobject/data/b_mapped/248.json
#  saving mapped collection data file: digitalobject/data/b_mapped/249.json
#  saving mapped collection data file: digitalobject/data/b_mapped/250.json
#  saving mapped collection data file: digitalobject/data/b_mapped/251.json
#  saving mapped collection data file: digitalobject/data/b_mapped/252.json
#  saving mapped collection data file: digitalobject/data/b_mapped/253.json
#  saving mapped collection data file: digitalobject/data/b_mapped/254.json
#  saving mapped collection data file: digitalobject/data/b_mapped/255.json
#  saving mapped collection data file: digitalobject/data/b_mapped/256.json
#  saving mapped collection data file: digitalobject/data/b_mapped/257.json
#  saving mapped collection data file: digitalobject/data/b_mapped/258.json
#  saving mapped collection data file: digitalobject/data/b_mapped/259.json
#  saving mapped collection data file: digitalobject/data/b_mapped/260.json
#  saving mapped collection data file: digitalobject/data/b_mapped/261.json
#  saving mapped collection data file: digitalobject/data/b_mapped/262.json
#  saving mapped collection data file: digitalobject/data/b_mapped/263.json
#  saving mapped collection data file: digitalobject/data/b_mapped/264.json
#  saving mapped collection data file: digitalobject/data/b_mapped/265.json
#  saving mapped collection data file: digitalobject/data/b_mapped/266.json
#  saving mapped collection data file: digitalobject/data/b_mapped/267.json
#  saving mapped collection data file: digitalobject/data/b_mapped/268.json
#  saving mapped collection data file: digitalobject/data/b_mapped/269.json
#  saving mapped collection data file: digitalobject/data/b_mapped/270.json
#  saving mapped collection data file: digitalobject/data/b_mapped/271.json
#  saving mapped collection data file: digitalobject/data/b_mapped/272.json
#  saving mapped collection data file: digitalobject/data/b_mapped/273.json
#  saving mapped collection data file: digitalobject/data/b_mapped/274.json
#  saving mapped collection data file: digitalobject/data/b_mapped/275.json
#  saving mapped collection data file: digitalobject/data/b_mapped/276.json
#  saving mapped collection data file: digitalobject/data/b_mapped/277.json
#  saving mapped collection data file: digitalobject/data/b_mapped/278.json
#  saving mapped collection data file: digitalobject/data/b_mapped/279.json
#  saving mapped collection data file: digitalobject/data/b_mapped/280.json
#  saving mapped collection data file: digitalobject/data/b_mapped/281.json
#  saving mapped collection data file: digitalobject/data/b_mapped/282.json
#  saving mapped collection data file: digitalobject/data/b_mapped/283.json
#  saving mapped collection data file: digitalobject/data/b_mapped/284.json
#  saving mapped collection data file: digitalobject/data/b_mapped/285.json
#  saving mapped collection data file: digitalobject/data/b_mapped/286.json
#  saving mapped collection data file: digitalobject/data/b_mapped/287.json
#  saving mapped collection data file: digitalobject/data/b_mapped/288.json
#  saving mapped collection data file: digitalobject/data/b_mapped/289.json
#  saving mapped collection data file: digitalobject/data/b_mapped/290.json
#  saving mapped collection data file: digitalobject/data/b_mapped/291.json
#  saving mapped collection data file: digitalobject/data/b_mapped/292.json
#  saving mapped collection data file: digitalobject/data/b_mapped/293.json
#  saving mapped collection data file: digitalobject/data/b_mapped/294.json
#  saving mapped collection data file: digitalobject/data/b_mapped/295.json
#  saving mapped collection data file: digitalobject/data/b_mapped/296.json
#  saving mapped collection data file: digitalobject/data/b_mapped/297.json
#  saving mapped collection data file: digitalobject/data/b_mapped/298.json
#  saving mapped collection data file: digitalobject/data/b_mapped/299.json
#  saving mapped collection data file: digitalobject/data/b_mapped/300.json
#  saving mapped collection data file: digitalobject/data/b_mapped/301.json
#  saving mapped collection data file: digitalobject/data/b_mapped/302.json
#  saving mapped collection data file: digitalobject/data/b_mapped/303.json
#  saving mapped collection data file: digitalobject/data/b_mapped/304.json
#  saving mapped collection data file: digitalobject/data/b_mapped/305.json
#  saving mapped collection data file: digitalobject/data/b_mapped/306.json
#  saving mapped collection data file: digitalobject/data/b_mapped/307.json
#  saving mapped collection data file: digitalobject/data/b_mapped/308.json
#  saving mapped collection data file: digitalobject/data/b_mapped/309.json
#  saving mapped collection data file: digitalobject/data/b_mapped/310.json
#  saving mapped collection data file: digitalobject/data/b_mapped/311.json
#  saving mapped collection data file: digitalobject/data/b_mapped/312.json
#  saving mapped collection data file: digitalobject/data/b_mapped/313.json
#  saving mapped collection data file: digitalobject/data/b_mapped/314.json
#  saving mapped collection data file: digitalobject/data/b_mapped/315.json
#  saving mapped collection data file: digitalobject/data/b_mapped/316.json
#  saving mapped collection data file: digitalobject/data/b_mapped/317.json
#  saving mapped collection data file: digitalobject/data/b_mapped/318.json
#  saving mapped collection data file: digitalobject/data/b_mapped/319.json
#  saving mapped collection data file: digitalobject/data/b_mapped/320.json
#  saving mapped collection data file: digitalobject/data/b_mapped/321.json
#  saving mapped collection data file: digitalobject/data/b_mapped/322.json
#  saving mapped collection data file: digitalobject/data/b_mapped/323.json
#  saving mapped collection data file: digitalobject/data/b_mapped/324.json
#  saving mapped collection data file: digitalobject/data/b_mapped/325.json
#  saving mapped collection data file: digitalobject/data/b_mapped/326.json
#  saving mapped collection data file: digitalobject/data/b_mapped/327.json
#  saving mapped collection data file: digitalobject/data/b_mapped/328.json
#  saving mapped collection data file: digitalobject/data/b_mapped/329.json
#  saving mapped collection data file: digitalobject/data/b_mapped/330.json
#  saving mapped collection data file: digitalobject/data/b_mapped/331.json
#  saving mapped collection data file: digitalobject/data/b_mapped/332.json
#  saving mapped collection data file: digitalobject/data/b_mapped/333.json
#  saving mapped collection data file: digitalobject/data/b_mapped/334.json
#  saving mapped collection data file: digitalobject/data/b_mapped/335.json
#  saving mapped collection data file: digitalobject/data/b_mapped/336.json
#  saving mapped collection data file: digitalobject/data/b_mapped/337.json
#  saving mapped collection data file: digitalobject/data/b_mapped/338.json
#  saving mapped collection data file: digitalobject/data/b_mapped/339.json
#  saving mapped collection data file: digitalobject/data/b_mapped/340.json
#  saving mapped collection data file: digitalobject/data/b_mapped/341.json
#  saving mapped collection data file: digitalobject/data/b_mapped/342.json
#  saving mapped collection data file: digitalobject/data/b_mapped/343.json
#  saving mapped collection data file: digitalobject/data/b_mapped/344.json
#  saving mapped collection data file: digitalobject/data/b_mapped/345.json
#  saving mapped collection data file: digitalobject/data/b_mapped/346.json
#  saving mapped collection data file: digitalobject/data/b_mapped/347.json
#  saving mapped collection data file: digitalobject/data/b_mapped/348.json
#  saving mapped collection data file: digitalobject/data/b_mapped/349.json
#  saving mapped collection data file: digitalobject/data/b_mapped/350.json
#  saving mapped collection data file: digitalobject/data/b_mapped/351.json
#  saving mapped collection data file: digitalobject/data/b_mapped/352.json
#  saving mapped collection data file: digitalobject/data/b_mapped/353.json
#  saving mapped collection data file: digitalobject/data/b_mapped/354.json
#  saving mapped collection data file: digitalobject/data/b_mapped/355.json
#  saving mapped collection data file: digitalobject/data/b_mapped/356.json
#  saving mapped collection data file: digitalobject/data/b_mapped/357.json
#  saving mapped collection data file: digitalobject/data/b_mapped/358.json
#  saving mapped collection data file: digitalobject/data/b_mapped/359.json
#  saving mapped collection data file: digitalobject/data/b_mapped/360.json
#  saving mapped collection data file: digitalobject/data/b_mapped/361.json
#  saving mapped collection data file: digitalobject/data/b_mapped/362.json
#  saving mapped collection data file: digitalobject/data/b_mapped/363.json
#  saving mapped collection data file: digitalobject/data/b_mapped/364.json
#  saving mapped collection data file: digitalobject/data/b_mapped/365.json
#  saving mapped collection data file: digitalobject/data/b_mapped/366.json
#  saving mapped collection data file: digitalobject/data/b_mapped/367.json
#  saving mapped collection data file: digitalobject/data/b_mapped/368.json
#  saving mapped collection data file: digitalobject/data/b_mapped/369.json
#  saving mapped collection data file: digitalobject/data/b_mapped/370.json
#  saving mapped collection data file: digitalobject/data/b_mapped/371.json
#  saving mapped collection data file: digitalobject/data/b_mapped/372.json
#  saving mapped collection data file: digitalobject/data/b_mapped/373.json
#  saving mapped collection data file: digitalobject/data/b_mapped/374.json
#  saving mapped collection data file: digitalobject/data/b_mapped/375.json
#  saving mapped collection data file: digitalobject/data/b_mapped/376.json
#  saving mapped collection data file: digitalobject/data/b_mapped/377.json
#  saving mapped collection data file: digitalobject/data/b_mapped/378.json
#  saving mapped collection data file: digitalobject/data/b_mapped/379.json
#  saving mapped collection data file: digitalobject/data/b_mapped/380.json
#  saving mapped collection data file: digitalobject/data/b_mapped/381.json
#  saving mapped collection data file: digitalobject/data/b_mapped/382.json
#  saving mapped collection data file: digitalobject/data/b_mapped/383.json
#  saving mapped collection data file: digitalobject/data/b_mapped/384.json
#  saving mapped collection data file: digitalobject/data/b_mapped/385.json
#  saving mapped collection data file: digitalobject/data/b_mapped/386.json
#  saving mapped collection data file: digitalobject/data/b_mapped/387.json
#  saving mapped collection data file: digitalobject/data/b_mapped/388.json
#  saving mapped collection data file: digitalobject/data/b_mapped/389.json
#  saving mapped collection data file: digitalobject/data/b_mapped/390.json
#  saving mapped collection data file: digitalobject/data/b_mapped/391.json
#  saving mapped collection data file: digitalobject/data/b_mapped/392.json
#  saving mapped collection data file: digitalobject/data/b_mapped/393.json
#  saving mapped collection data file: digitalobject/data/b_mapped/394.json
#  saving mapped collection data file: digitalobject/data/b_mapped/395.json
#  saving mapped collection data file: digitalobject/data/b_mapped/396.json
#  saving mapped collection data file: digitalobject/data/b_mapped/397.json
#  saving mapped collection data file: digitalobject/data/b_mapped/398.json
#  saving mapped collection data file: digitalobject/data/b_mapped/399.json
#  saving mapped collection data file: digitalobject/data/b_mapped/400.json
#  saving mapped collection data file: digitalobject/data/b_mapped/401.json
#  saving mapped collection data file: digitalobject/data/b_mapped/402.json
#  saving mapped collection data file: digitalobject/data/b_mapped/403.json
#  saving mapped collection data file: digitalobject/data/b_mapped/404.json
#  saving mapped collection data file: digitalobject/data/b_mapped/405.json
#  saving mapped collection data file: digitalobject/data/b_mapped/406.json
#  saving mapped collection data file: digitalobject/data/b_mapped/407.json
#  saving mapped collection data file: digitalobject/data/b_mapped/408.json
#  saving mapped collection data file: digitalobject/data/b_mapped/409.json
#  saving mapped collection data file: digitalobject/data/b_mapped/410.json
#  saving mapped collection data file: digitalobject/data/b_mapped/411.json
#  saving mapped collection data file: digitalobject/data/b_mapped/412.json
#  saving mapped collection data file: digitalobject/data/b_mapped/413.json
#  saving mapped collection data file: digitalobject/data/b_mapped/414.json
#  saving mapped collection data file: digitalobject/data/b_mapped/415.json
#  saving mapped collection data file: digitalobject/data/b_mapped/416.json
#  saving mapped collection data file: digitalobject/data/b_mapped/417.json
#  saving mapped collection data file: digitalobject/data/b_mapped/418.json
#  saving mapped collection data file: digitalobject/data/b_mapped/419.json
#  saving mapped collection data file: digitalobject/data/b_mapped/420.json
#  saving mapped collection data file: digitalobject/data/b_mapped/421.json
#  saving mapped collection data file: digitalobject/data/b_mapped/422.json
#  saving mapped collection data file: digitalobject/data/b_mapped/423.json
#  saving mapped collection data file: digitalobject/data/b_mapped/424.json
#  saving mapped collection data file: digitalobject/data/b_mapped/425.json
#  saving mapped collection data file: digitalobject/data/b_mapped/426.json
#  saving mapped collection data file: digitalobject/data/b_mapped/427.json
#  saving mapped collection data file: digitalobject/data/b_mapped/428.json
#  saving mapped collection data file: digitalobject/data/b_mapped/429.json
#  saving mapped collection data file: digitalobject/data/b_mapped/430.json
#  saving mapped collection data file: digitalobject/data/b_mapped/431.json
#  saving mapped collection data file: digitalobject/data/b_mapped/432.json
#  saving mapped collection data file: digitalobject/data/b_mapped/433.json
#  saving mapped collection data file: digitalobject/data/b_mapped/434.json
#  saving mapped collection data file: digitalobject/data/b_mapped/435.json
#  saving mapped collection data file: digitalobject/data/b_mapped/436.json
#  saving mapped collection data file: digitalobject/data/b_mapped/437.json
#  saving mapped collection data file: digitalobject/data/b_mapped/438.json
#  saving mapped collection data file: digitalobject/data/b_mapped/439.json
#  saving mapped collection data file: digitalobject/data/b_mapped/440.json
#  saving mapped collection data file: digitalobject/data/b_mapped/441.json
#  saving mapped collection data file: digitalobject/data/b_mapped/442.json
#  saving mapped collection data file: digitalobject/data/b_mapped/443.json
#  saving mapped collection data file: digitalobject/data/b_mapped/444.json
#  saving mapped collection data file: digitalobject/data/b_mapped/445.json
#  saving mapped collection data file: digitalobject/data/b_mapped/446.json
#  saving mapped collection data file: digitalobject/data/b_mapped/447.json
#  saving mapped collection data file: digitalobject/data/b_mapped/448.json
#  saving mapped collection data file: digitalobject/data/b_mapped/449.json
#  saving mapped collection data file: digitalobject/data/b_mapped/450.json
#  saving mapped collection data file: digitalobject/data/b_mapped/451.json
#  saving mapped collection data file: digitalobject/data/b_mapped/452.json
#  saving mapped collection data file: digitalobject/data/b_mapped/453.json
#  saving mapped collection data file: digitalobject/data/b_mapped/454.json
#  saving mapped collection data file: digitalobject/data/b_mapped/455.json
#  saving mapped collection data file: digitalobject/data/b_mapped/456.json
#  saving mapped collection data file: digitalobject/data/b_mapped/457.json
#  saving mapped collection data file: digitalobject/data/b_mapped/458.json
#  saving mapped collection data file: digitalobject/data/b_mapped/459.json
#  saving mapped collection data file: digitalobject/data/b_mapped/460.json
#  saving mapped collection data file: digitalobject/data/b_mapped/461.json
#  saving mapped collection data file: digitalobject/data/b_mapped/462.json
#  saving mapped collection data file: digitalobject/data/b_mapped/463.json
#  saving mapped collection data file: digitalobject/data/b_mapped/464.json
#  saving mapped collection data file: digitalobject/data/b_mapped/465.json
#  saving mapped collection data file: digitalobject/data/b_mapped/466.json
#  saving mapped collection data file: digitalobject/data/b_mapped/467.json
#  saving mapped collection data file: digitalobject/data/b_mapped/468.json
#  saving mapped collection data file: digitalobject/data/b_mapped/469.json
#  saving mapped collection data file: digitalobject/data/b_mapped/470.json
#  saving mapped collection data file: digitalobject/data/b_mapped/471.json
#  saving mapped collection data file: digitalobject/data/b_mapped/472.json
#  saving mapped collection data file: digitalobject/data/b_mapped/473.json
#  saving mapped collection data file: digitalobject/data/b_mapped/474.json
#  saving mapped collection data file: digitalobject/data/b_mapped/475.json
#  saving mapped collection data file: digitalobject/data/b_mapped/476.json
#  saving mapped collection data file: digitalobject/data/b_mapped/477.json
#  saving mapped collection data file: digitalobject/data/b_mapped/478.json
#  saving mapped collection data file: digitalobject/data/b_mapped/479.json
#  saving mapped collection data file: digitalobject/data/b_mapped/480.json
#  saving mapped collection data file: digitalobject/data/b_mapped/481.json
#  saving mapped collection data file: digitalobject/data/b_mapped/482.json
#  saving mapped collection data file: digitalobject/data/b_mapped/483.json
#  saving mapped collection data file: digitalobject/data/b_mapped/484.json
#  saving mapped collection data file: digitalobject/data/b_mapped/485.json
#  saving mapped collection data file: digitalobject/data/b_mapped/486.json
#  saving mapped collection data file: digitalobject/data/b_mapped/487.json
#  saving mapped collection data file: digitalobject/data/b_mapped/488.json
#  saving mapped collection data file: digitalobject/data/b_mapped/489.json
#  saving mapped collection data file: digitalobject/data/b_mapped/490.json
#  saving mapped collection data file: digitalobject/data/b_mapped/491.json
#  saving mapped collection data file: digitalobject/data/b_mapped/492.json
#  saving mapped collection data file: digitalobject/data/b_mapped/493.json
#  saving mapped collection data file: digitalobject/data/b_mapped/494.json
#  saving mapped collection data file: digitalobject/data/b_mapped/495.json
#  saving mapped collection data file: digitalobject/data/b_mapped/496.json
#  saving mapped collection data file: digitalobject/data/b_mapped/497.json
#  saving mapped collection data file: digitalobject/data/b_mapped/498.json
#  saving mapped collection data file: digitalobject/data/b_mapped/499.json
#  saving mapped collection data file: digitalobject/data/b_mapped/500.json
